# %% [markdown]
# <a href="https://colab.research.google.com/github/kryssiamendonca/projeto_analise_salesdata/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Upload DataBase

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-07b3f280-dead-4ecc-a5c2-fcef1aeb5b23" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07b3f280-dead-4ecc-a5c2-fcef1aeb5b23">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 1. Importar bibliotecas
import pandas as pd
import numpy as np

# 2. Nome do arquivo (substitua se precisar)
arquivo = 'sales_data_sample (1).csv'

# 3. Carregar o dataset com a codificação correta
df = pd.read_csv(arquivo, encoding='ISO-8859-1')

# 4. Mostrar as primeiras linhas
print("=== Primeiras linhas ===")
print(df.head())

# 5. Mostrar informações do dataset
print("\n=== Info do DataFrame ===")
print(df.info())

# 6. Mostrar tamanho (shape)
print(f"\nShape do dataset: {df.shape}")

# 7. Mostrar colunas
print("\nColunas:")
print(df.columns.tolist())

# 8. Estatísticas básicas
print("\nEstatísticas descritivas:")
print(df.describe(include='all'))
# Out:
# === Primeiras linhas ===
#   ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0       10107             30.0      95.70              2.0  2871.00
# 1       10121             34.0      81.35              5.0  2765.90
# 2       10134             41.0      94.74              2.0  3884.34
# 3       10145             45.0      83.26              6.0  3746.70
# 4       10159             49.0     100.00             14.0  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped     1.0       2.0   2003.0  ...
# 1    5/7/2003 0:00  Shipped     2.0       5.0   2003.0  ...
# 2    7/1/2003 0:00  Shipped     3.0       7.0   2003.0  ...
# 3   8/25/2003 0:00  Shipped     3.0       8.0   2003.0  ...
# 4  10/10/2003 0:00  Shipped     4.0      10.0   2003.0  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...
